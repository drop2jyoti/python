# %% [markdown]
# # Functions
# ## Practice Problems

# %% [markdown]
# ### 1. Following the function design recipe, define:
#   * a function that converts Fahrenheit into Celsius
#   * a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
# Your code goes here
def temperature_conversion(temp, type):
    if type == "c":
        return (temp -32) * 5/9
    elif type =="f":
        return (temp * 9 /5) + 32

print(temperature_conversion(95, "c"))
print(temperature_conversion(35, "f"))


def distance_conversion(distance, type):
    if type =="miles":
        return distance * 0.6214
    elif type == "km":
        return distance *1.6
    
print(distance_conversion(100, "miles"))
print(distance_conversion(62 , "km"))
# Out:
# 35.0
# 95.0
# 62.13999999999999
# 99.2

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#   <pre>
#     def fahrenheit_to_celsius(fahrenheit):
#       celsius = (fahrenheit - 32) * 5 / 9
#       return celsius
#     temp_in_celsius = fahrenheit_to_celsius(98.6)
#     print(temp_in_celsius)
#   </pre>
#
# </details>

# %% [markdown]
# ### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer
    
answer_to_everything()

print(answer) # 3
# Out:
# 3

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   Answer: 3. The answer variable in our function is locally scoped -- our program cannot access the value 42 from outside of the function, including when we called print(answer).
#
#   Although we called answer_to_everything(), we did not assign the output to a variable.
# </details>

# %% [markdown]
# ### 3. Complete the examples in the docstring below, then write the body of the function. You can assume `num` is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    # your expected output here
    >>> repeat('yesnomaybe', 3)
    # your expected output here
    '''
    output = string*num
    return output

print(repeat('no', 0))
print(repeat('yes', 4))
print(repeat('yesnomaybe',3))
# Out:
# yesyesyesyes
# yesnomaybeyesnomaybeyesnomaybe

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#   <pre>
#     from pickle import TRUE
#     def repeat(string, num):
#       ''' Return string repeated num times.
#       >>> repeat('yes', 4)
#       'yesyesyesyes'
#       >>> repeat('no', 0)
#       >>> repeat('yesnomaybe', 3)
#       yesnomaybeyesnomaybeyesnomaybe
#       '''
#       output = string*num
#       return output
#   </pre>
#
# </details>

# %% [markdown]
# ### 4. Complete the function below. You can assume that `number` will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
from pickle import TRUE
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # Your code goes here
    number = number.replace('(', "")
    number = number.replace(')', "")
    print("Sanitized number : ", number)
    res = number[0: 3] == '416'
    return res


print(is_416_number('(416)-555-5555'))
print(is_416_number('514 416 5555'))
print(is_416_number('4165554160'))
# Out:
# Sanitized number :  416-555-5555
# True
# Sanitized number :  514 416 5555
# False
# Sanitized number :  4165554160
# True

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#   <pre>
#     from pickle import TRUE
#     def is_416_number(number):
#         ''' Check whether the number has a 416 area code.
#         >>> is_416_number('(416)-555-5555')
#         True
#         >>> is_416_number('514 416 5555')
#         False
#         >>> is_416_number('4165554160')
#         True
#         '''
#         # replace parens w/ nothing
#         number = number.replace('(', '')
#         number = number.replace(')', '')
#         output = number[:3] == '416'
#         return output
#   </pre>
#
# </details>
